# %% [markdown]
# <a href="https://colab.research.google.com/github/mamuncseru/opencv-learning/blob/main/OpenCV_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Copy of CATS_DOGS.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CATS_DOGS/train/DOG/4934.jpg
#   inflating: CATS_DOGS/train/DOG/4935.jpg
#   inflating: CATS_DOGS/train/DOG/4936.jpg
#   inflating: CATS_DOGS/train/DOG/4937.jpg
#   inflating: CATS_DOGS/train/DOG/4938.jpg
#   inflating: CATS_DOGS/train/DOG/4939.jpg
#   inflating: CATS_DOGS/train/DOG/494.jpg
#   inflating: CATS_DOGS/train/DOG/4940.jpg
#   inflating: CATS_DOGS/train/DOG/4941.jpg
#   inflating: CATS_DOGS/train/DOG/4942.jpg
#   inflating: CATS_DOGS/train/DOG/4943.jpg
#   inflating: CATS_DOGS/train/DOG/4944.jpg
#   inflating: CATS_DOGS/train/DOG/4945.jpg
#   inflating: CATS_DOGS/train/DOG/4946.jpg
#   inflating: CATS_DOGS/train/DOG/4947.jpg
#   inflating: CATS_DOGS/train/DOG/4948.jpg
#   inflating: CATS_DOGS/train/DOG/4949.jpg
#   inflating: CATS_DOGS/train/DOG/495.jpg
#   inflating: CATS_DOGS/train/DOG/4950.jpg
#   inflating: CATS_DOGS/train/DOG/4951.jpg
#   inflating: CATS_DOGS/train/DOG/4952.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/Copy of Computer-Vision-with-Python.zip"
# Out:
# Archive:  /content/drive/MyDrive/Copy of Computer-Vision-with-Python.zip
#    creating: Computer-Vision-with-Python/
#    creating: Computer-Vision-with-Python/.git/
#  extracting: Computer-Vision-with-Python/.git/COMMIT_EDITMSG
#   inflating: Computer-Vision-with-Python/.git/config
#   inflating: Computer-Vision-with-Python/.git/description
#   inflating: Computer-Vision-with-Python/.git/FETCH_HEAD
#  extracting: Computer-Vision-with-Python/.git/HEAD
#    creating: Computer-Vision-with-Python/.git/hooks/
#   inflating: Computer-Vision-with-Python/.git/hooks/applypatch-msg.sample
#   inflating: Computer-Vision-with-Python/.git/hooks/commit-msg.sample
#   inflating: Computer-Vision-with-Python/.git/hooks/post-update.sample
#   inflating: Computer-Vision-with-Python/.git/hooks/pre-applypatch.sample
#   inflating: Computer-Vision-with-Python/.git/hooks/pre-commit.sample
#   inflating: Computer-Vision-with-Python/.git/hooks/pre-push.sample
# ...

# %%
# %cd Computer-Vision-with-Python/
# Out:
# /content/Computer-Vision-with-Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)
